# %%
import pandas as pd
from sqlalchemy import create_engine
import boto3
from io import StringIO

# ----------------------------
# 1. Paramètres S3
# ----------------------------
bucket_name = "data-lake-ensae-projet-9"
folder = "raw/"

# Liste des fichiers CSV
csv_files = [
    # "olist_customers_dataset.csv",
    # "olist_geolocation_dataset.csv",
    # "olist_order_items_dataset.csv",
    # "olist_order_payments_dataset.csv",
    "olist_order_reviews_dataset.csv",
    # "olist_orders_dataset.csv",
    "olist_products_dataset.csv",
    # "olist_sellers_dataset.csv",
    # "product_category_name_translation.csv"
]

# ----------------------------
# 2. Connexion S3
# ----------------------------
s3 = boto3.client('s3')

# ----------------------------
# 3. Connexion RDS MySQL
# ----------------------------
username = "admin"
password = "groupe1_mously"
host = "database-2.cala4g8gsyma.us-east-1.rds.amazonaws.com"
database = "MA_BASE"  # tu peux mettre un nom pour ta DB si nécessaire

engine = create_engine(f"mysql+pymysql://{username}:{password}@{host}:3306/{database}")

# ----------------------------
# 4. Boucle pour chaque fichier CSV
# ----------------------------
for file in csv_files:
    file_key = folder + file
    print(f" Récupération du fichier {file_key} depuis S3 ...")
    
    csv_obj = s3.get_object(Bucket=bucket_name, Key=file_key)
    body = csv_obj['Body'].read().decode('utf-8')
    df = pd.read_csv(StringIO(body))
    
    table_name = file.replace(".csv", "")
    print(f" Chargement dans la table RDS : {table_name}")
    
    df.to_sql(table_name, engine, if_exists="replace", index=False)

print(" Tous les fichiers ont été chargés dans RDS avec succès !")
# Out:
#  Récupération du fichier raw/olist_order_reviews_dataset.csv depuis S3 ...
#  Chargement dans la table RDS : olist_order_reviews_dataset
#  Récupération du fichier raw/olist_products_dataset.csv depuis S3 ...
#  Chargement dans la table RDS : olist_products_dataset
#  Tous les fichiers ont été chargés dans RDS avec succès !

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\hp\anaconda3\python.exe

# %%
# Installer boto3
# !conda install -c conda-forge boto3 -y

# Installer les autres bibliothèques si nécessaire
# !conda install -c conda-forge pandas sqlalchemy pymysql -y
# Out:
# Channels:
#  - conda-forge
#  - defaults
# Platform: win-64
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\hp\anaconda3
#
#   added / updated specs:
#     - boto3
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     aiobotocore-2.25.2         |     pyhcf101f3_0          79 KB  conda-forge
#     boto3-1.40.70              |     pyhd8ed1ab_0          82 KB  conda-forge
#     botocore-1.40.70           |     pyhd8ed1ab_0         7.8 MB  conda-forge
#     ca-certificates-2025.11.12 |       h4c7d964_0         149 KB  conda-forge
#     certifi-2025.11.12         |     pyhd8ed1ab_0         153 KB  conda-forge
#     conda-24.11.3              |  py312h2e8e312_0         1.1 MB  conda-forge
#     openssl-3.6.0              |       h725018a_0         9.0 MB  conda-forge
#     python_abi-3.12            |          3_cp312           6 KB
#     s3transfer-0.14.0          |     pyhd8ed1ab_0          64 KB  conda-forge
#     ucrt-10.0.26100.0          |       h57928b3_0         678 KB  conda-forge
#     vc14_runtime-14.44.35208   |      h818238b_32         667 KB  conda-forge
#     vcomp14-14.44.35208        |      h818238b_32         112 KB  conda-forge
#     vs2015_runtime-14.44.35208 |      h38c0c73_32          18 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        19.9 MB
#
# The following NEW packages will be INSTALLED:
#
#   boto3              conda-forge/noarch::boto3-1.40.70-pyhd8ed1ab_0
#   python_abi         pkgs/main/win-64::python_abi-3.12-3_cp312
#   s3transfer         conda-forge/noarch::s3transfer-0.14.0-pyhd8ed1ab_0
#   ucrt               conda-forge/win-64::ucrt-10.0.26100.0-h57928b3_0
#   vc14_runtime       conda-forge/win-64::vc14_runtime-14.44.35208-h818238b_32
#   vcomp14            conda-forge/win-64::vcomp14-14.44.35208-h818238b_32
#
# The following packages will be UPDATED:
#
#   aiobotocore        pkgs/main/win-64::aiobotocore-2.12.3-~ --> conda-forge/noarch::aiobotocore-2.25.2-pyhcf101f3_0
#   botocore           pkgs/main/win-64::botocore-1.34.69-py~ --> conda-forge/noarch::botocore-1.40.70-pyhd8ed1ab_0
#   ca-certificates    pkgs/main/win-64::ca-certificates-202~ --> conda-forge/noarch::ca-certificates-2025.11.12-h4c7d964_0
#   certifi            pkgs/main/win-64::certifi-2025.1.31-p~ --> conda-forge/noarch::certifi-2025.11.12-pyhd8ed1ab_0
#   openssl              pkgs/main::openssl-3.0.16-h3f729d1_0 --> conda-forge::openssl-3.6.0-h725018a_0
#   vs2015_runtime     pkgs/main::vs2015_runtime-14.40.33807~ --> conda-forge::vs2015_runtime-14.44.35208-h38c0c73_32
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   conda              pkgs/main::conda-24.11.3-py312haa9553~ --> conda-forge::conda-24.11.3-py312h2e8e312_0
#
#
#
# Downloading and Extracting Packages: ...working...
# openssl-3.6.0        | 9.0 MB    |            |   0%
#
# botocore-1.40.70     | 7.8 MB    |            |   0%
#
#
# conda-24.11.3        | 1.1 MB    |            |   0%
#
#
#
# ucrt-10.0.26100.0    | 678 KB    |            |   0%
#
#
#
#
# vc14_runtime-14.44.3 | 667 KB    |            |   0%
#
#
#
#
#
# certifi-2025.11.12   | 153 KB    |            |   0%
#
#
#
#
#
#
# ca-certificates-2025 | 149 KB    |            |   0%
#
#
#
#
#
#
#
# vcomp14-14.44.35208  | 112 KB    |            |   0%
#
#
#
#
#
#
#
#
# boto3-1.40.70        | 82 KB     |            |   0%
#
#
#
#
#
#
#
#
#
# aiobotocore-2.25.2   | 79 KB     |            |   0%
#
#
#
#
#
#
#
#
#
#
# s3transfer-0.14.0    | 64 KB     |            |   0%
#
#
#
#
#
#
#
#
#
#
#
# vs2015_runtime-14.44 | 18 KB     |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# python_abi-3.12      | 6 KB      |            |   0%
# openssl-3.6.0        | 9.0 MB    |            |   0%
#
#
#
# ucrt-10.0.26100.0    | 678 KB    | 2          |   2%
#
#
#
#
# vc14_runtime-14.44.3 | 667 KB    | 2          |   2%
# openssl-3.6.0        | 9.0 MB    | 1          |   1%
#
#
#
# ucrt-10.0.26100.0    | 678 KB    | #8         |  19%
# openssl-3.6.0        | 9.0 MB    | 2          |   3%
#
#
#
#
# vc14_runtime-14.44.3 | 667 KB    | #9         |  19%
#
#
#
# ucrt-10.0.26100.0    | 678 KB    | ##8        |  28%
#
#
#
# ucrt-10.0.26100.0    | 678 KB    | ###7       |  38%
#
#
#
#
# vc14_runtime-14.44.3 | 667 KB    | ###5       |  36%
# openssl-3.6.0        | 9.0 MB    | 3          |   3%
#
#
# conda-24.11.3        | 1.1 MB    | 1          |   1%
#
#
#
# ucrt-10.0.26100.0    | 678 KB    | ####7      |  47%
# openssl-3.6.0        | 9.0 MB    | 4          |   4%
#
#
#
#
# vc14_runtime-14.44.3 | 667 KB    | ####7      |  48%
#
#
#
# ucrt-10.0.26100.0    | 678 KB    | #####6     |  57%
# openssl-3.6.0        | 9.0 MB    | 4          |   5%
#
#
# conda-24.11.3        | 1.1 MB    | #1         |  11%
#
#
#
# ucrt-10.0.26100.0    | 678 KB    | ######3    |  64%
#
#
#
#
# vc14_runtime-14.44.3 | 667 KB    | #####7     |  58%
#
#
# conda-24.11.3        | 1.1 MB    | ##2        |  22%
#
#
# conda-24.11.3        | 1.1 MB    | ##6        |  26%
#
#
#
# ucrt-10.0.26100.0    | 678 KB    | #######5   |  75%
# openssl-3.6.0        | 9.0 MB    | 5          |   6%
#
#
# conda-24.11.3        | 1.1 MB    | ###3       |  33%
#
# botocore-1.40.70     | 7.8 MB    |            |   0%
#
#
# conda-24.11.3        | 1.1 MB    | ###7       |  38%
#
#
#
#
# vc14_runtime-14.44.3 | 667 KB    | #######4   |  74%
#
#
#
# ucrt-10.0.26100.0    | 678 KB    | #########4 |  94%
# openssl-3.6.0        | 9.0 MB    | 6          |   7%
#
#
#
# ucrt-10.0.26100.0    | 678 KB    | ########## | 100%
# openssl-3.6.0        | 9.0 MB    | 7          |   8%
#
#
#
#
# vc14_runtime-14.44.3 | 667 KB    | #########3 |  94%
#
#
# conda-24.11.3        | 1.1 MB    | ####5      |  46%
# openssl-3.6.0        | 9.0 MB    | 8          |   9%
#
# botocore-1.40.70     | 7.8 MB    | 1          |   2%
#
#
#
#
#
# certifi-2025.11.12   | 153 KB    | #          |  10%
#
#
#
# ucrt-10.0.26100.0    | 678 KB    | ########## | 100%
#
#
#
# ucrt-10.0.26100.0    | 678 KB    | ########## | 100%
# openssl-3.6.0        | 9.0 MB    | 9          |   9%
#
#
#
#
# vc14_runtime-14.44.3 | 667 KB    | #########8 |  98%
#
#
# conda-24.11.3        | 1.1 MB    | ####8      |  49%
#
#
#
#
#
# certifi-2025.11.12   | 153 KB    | ###1       |  31%
#
# botocore-1.40.70     | 7.8 MB    | 3          |   3%
# openssl-3.6.0        | 9.0 MB    | 9          |  10%
#
#
#
#
#
# certifi-2025.11.12   | 153 KB    | ####1      |  42%
#
# botocore-1.40.70     | 7.8 MB    | 3          |   4%
#
#
#
#
#
# certifi-2025.11.12   | 153 KB    | ########## | 100%
# openssl-3.6.0        | 9.0 MB    | #          |  10%
#
#
#
#
# vc14_runtime-14.44.3 | 667 KB    | ########## | 100%
#
# botocore-1.40.70     | 7.8 MB    | 5          |   6%
#
#
# conda-24.11.3        | 1.1 MB    | #####8     |  59%
# openssl-3.6.0        | 9.0 MB    | #          |  11%
#
#
#
#
#
# certifi-2025.11.12   | 153 KB    | ########## | 100%
#
#
#
#
#
# certifi-2025.11.12   | 153 KB    | ########## | 100%
#
#
# conda-24.11.3        | 1.1 MB    | ######5    |  65%
# openssl-3.6.0        | 9.0 MB    | #1         |  12%
#
#
#
#
#
#
# ca-certificates-2025 | 149 KB    | #          |  11%
#
#
#
#
# vc14_runtime-14.44.3 | 667 KB    | ########## | 100%
#
# botocore-1.40.70     | 7.8 MB    | 6          |   7%
#
# botocore-1.40.70     | 7.8 MB    | 8          |   8%
#
#
#
#
#
#
# ca-certificates-2025 | 149 KB    | ###2       |  32%
# openssl-3.6.0        | 9.0 MB    | #2         |  12%
#
#
# conda-24.11.3        | 1.1 MB    | ######9    |  70%
#
#
#
#
#
#
#
# vcomp14-14.44.35208  | 112 KB    | #4         |  14%
#
# botocore-1.40.70     | 7.8 MB    | 9          |  10%
#
#
#
#
#
#
# ca-certificates-2025 | 149 KB    | ######4    |  64%
#
#
# conda-24.11.3        | 1.1 MB    | #######3   |  74%
# openssl-3.6.0        | 9.0 MB    | #3         |  13%
#
#
#
#
#
#
#
# vcomp14-14.44.35208  | 112 KB    | #####7     |  57%
#
# botocore-1.40.70     | 7.8 MB    | #          |  11%
#
# botocore-1.40.70     | 7.8 MB    | #2         |  12%
#
#
#
#
#
#
# ca-certificates-2025 | 149 KB    | ########5  |  86%
# openssl-3.6.0        | 9.0 MB    | #3         |  14%
#
#
#
#
#
#
# ca-certificates-2025 | 149 KB    | ########## | 100%
#
#
# conda-24.11.3        | 1.1 MB    | #######8   |  78%
#
#
#
#
#
#
#
# vcomp14-14.44.35208  | 112 KB    | ########5  |  86%
#
#
#
#
#
#
#
# vcomp14-14.44.35208  | 112 KB    | ########## | 100%
#
#
#
#
#
#
# ca-certificates-2025 | 149 KB    | ########## | 100%
#
#
#
#
#
#
# ca-certificates-2025 | 149 KB    | ########## | 100%
#
# botocore-1.40.70     | 7.8 MB    | #3         |  14%
#
#
#
#
#
#
#
# vcomp14-14.44.35208  | 112 KB    | ########## | 100%
#
# botocore-1.40.70     | 7.8 MB    | #5         |  15%
#
#
# conda-24.11.3        | 1.1 MB    | ########3  |  84%
# openssl-3.6.0        | 9.0 MB    | #5         |  15%
#
# botocore-1.40.70     | 7.8 MB    | #6         |  16%
# openssl-3.6.0        | 9.0 MB    | #5         |  16%
#
#
# conda-24.11.3        | 1.1 MB    | ########9  |  89%
#
# botocore-1.40.70     | 7.8 MB    | #7         |  18%
# openssl-3.6.0        | 9.0 MB    | #6         |  16%
#
# botocore-1.40.70     | 7.8 MB    | #9         |  20%
#
#
#
#
#
#
#
#
# boto3-1.40.70        | 82 KB     | #9         |  20%
#
#
# conda-24.11.3        | 1.1 MB    | #########3 |  93%
#
#
#
#
#
#
#
#
# boto3-1.40.70        | 82 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
# aiobotocore-2.25.2   | 79 KB     | ##         |  20%
# openssl-3.6.0        | 9.0 MB    | #7         |  17%
#
# botocore-1.40.70     | 7.8 MB    | ##         |  21%
#
#
# conda-24.11.3        | 1.1 MB    | #########6 |  96%
#
# botocore-1.40.70     | 7.8 MB    | ##2        |  22%
# openssl-3.6.0        | 9.0 MB    | #7         |  18%
#
#
# conda-24.11.3        | 1.1 MB    | #########8 |  99%
#
#
# conda-24.11.3        | 1.1 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
# aiobotocore-2.25.2   | 79 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
# aiobotocore-2.25.2   | 79 KB     | ########## | 100%
#
# botocore-1.40.70     | 7.8 MB    | ##3        |  24%
# openssl-3.6.0        | 9.0 MB    | #8         |  18%
#
# botocore-1.40.70     | 7.8 MB    | ##5        |  25%
#
#
#
#
#
#
#
#
# boto3-1.40.70        | 82 KB     | ########## | 100%
#
#
#
#
#
#
#
#
# boto3-1.40.70        | 82 KB     | ########## | 100%
#
# botocore-1.40.70     | 7.8 MB    | ##7        |  28%
#
#
#
#
#
#
#
#
#
#
# s3transfer-0.14.0    | 64 KB     | ##4        |  25%
# openssl-3.6.0        | 9.0 MB    | #8         |  19%
#
#
#
#
#
#
#
#
#
# aiobotocore-2.25.2   | 79 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
# vs2015_runtime-14.44 | 18 KB     | ########6  |  87%
#
#
#
#
#
#
#
#
#
#
#
# vs2015_runtime-14.44 | 18 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
# s3transfer-0.14.0    | 64 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
# vs2015_runtime-14.44 | 18 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
# vs2015_runtime-14.44 | 18 KB     | ########## | 100%
# openssl-3.6.0        | 9.0 MB    | #9         |  19%
#
# botocore-1.40.70     | 7.8 MB    | ##9        |  29%
#
#
#
#
#
#
#
#
#
#
# s3transfer-0.14.0    | 64 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
# s3transfer-0.14.0    | 64 KB     | ########## | 100%
#
# botocore-1.40.70     | 7.8 MB    | ###        |  31%
# openssl-3.6.0        | 9.0 MB    | #9         |  20%
# openssl-3.6.0        | 9.0 MB    | ##         |  20%
#
# botocore-1.40.70     | 7.8 MB    | ###2       |  32%
# openssl-3.6.0        | 9.0 MB    | ##         |  21%
#
#
#
#
#
#
#
#
#
#
#
#
# python_abi-3.12      | 6 KB      | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# python_abi-3.12      | 6 KB      | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# python_abi-3.12      | 6 KB      | ########## | 100%
#
# botocore-1.40.70     | 7.8 MB    | ###3       |  34%
# openssl-3.6.0        | 9.0 MB    | ##1        |  21%
#
# botocore-1.40.70     | 7.8 MB    | ###4       |  35%
# openssl-3.6.0        | 9.0 MB    | ##1        |  22%
#
# botocore-1.40.70     | 7.8 MB    | ###6       |  36%
#
# botocore-1.40.70     | 7.8 MB    | ###7       |  37%
# openssl-3.6.0        | 9.0 MB    | ##2        |  22%
#
# botocore-1.40.70     | 7.8 MB    | ###8       |  39%
# openssl-3.6.0        | 9.0 MB    | ##2        |  23%
#
# botocore-1.40.70     | 7.8 MB    | ####       |  40%
# openssl-3.6.0        | 9.0 MB    | ##3        |  23%
#
# botocore-1.40.70     | 7.8 MB    | ####1      |  42%
# openssl-3.6.0        | 9.0 MB    | ##4        |  24%
#
# botocore-1.40.70     | 7.8 MB    | ####3      |  43%
# openssl-3.6.0        | 9.0 MB    | ##4        |  25%
#
# botocore-1.40.70     | 7.8 MB    | ####5      |  45%
# openssl-3.6.0        | 9.0 MB    | ##5        |  26%
#
# botocore-1.40.70     | 7.8 MB    | ####7      |  47%
#
#
# conda-24.11.3        | 1.1 MB    | ########## | 100%
#
# botocore-1.40.70     | 7.8 MB    | ####9      |  49%
# openssl-3.6.0        | 9.0 MB    | ##6        |  27%
#
# botocore-1.40.70     | 7.8 MB    | #####1     |  51%
# openssl-3.6.0        | 9.0 MB    | ##7        |  28%
# openssl-3.6.0        | 9.0 MB    | ##8        |  29%
#
# botocore-1.40.70     | 7.8 MB    | #####3     |  53%
#
# botocore-1.40.70     | 7.8 MB    | #####5     |  55%
# openssl-3.6.0        | 9.0 MB    | ##9        |  30%
#
# botocore-1.40.70     | 7.8 MB    | #####7     |  58%
# openssl-3.6.0        | 9.0 MB    | ###        |  31%
#
# botocore-1.40.70     | 7.8 MB    | ######     |  60%
# openssl-3.6.0        | 9.0 MB    | ###2       |  32%
#
# botocore-1.40.70     | 7.8 MB    | ######2    |  63%
# openssl-3.6.0        | 9.0 MB    | ###3       |  33%
#
# botocore-1.40.70     | 7.8 MB    | ######4    |  65%
# openssl-3.6.0        | 9.0 MB    | ###4       |  35%
#
# botocore-1.40.70     | 7.8 MB    | ######6    |  67%
# openssl-3.6.0        | 9.0 MB    | ###5       |  36%
#
# botocore-1.40.70     | 7.8 MB    | ######9    |  69%
# openssl-3.6.0        | 9.0 MB    | ###7       |  37%
# openssl-3.6.0        | 9.0 MB    | ###8       |  39%
#
# botocore-1.40.70     | 7.8 MB    | #######1   |  72%
# openssl-3.6.0        | 9.0 MB    | ####       |  40%
#
# botocore-1.40.70     | 7.8 MB    | #######3   |  74%
# openssl-3.6.0        | 9.0 MB    | ####1      |  41%
#
# botocore-1.40.70     | 7.8 MB    | #######5   |  76%
# openssl-3.6.0        | 9.0 MB    | ####2      |  42%
#
# botocore-1.40.70     | 7.8 MB    | #######7   |  78%
# openssl-3.6.0        | 9.0 MB    | ####3      |  43%
#
# botocore-1.40.70     | 7.8 MB    | #######9   |  80%
# openssl-3.6.0        | 9.0 MB    | ####4      |  45%
#
# botocore-1.40.70     | 7.8 MB    | ########1  |  81%
# openssl-3.6.0        | 9.0 MB    | ####6      |  46%
#
# botocore-1.40.70     | 7.8 MB    | ########3  |  84%
# openssl-3.6.0        | 9.0 MB    | ####7      |  47%
#
# botocore-1.40.70     | 7.8 MB    | ########6  |  86%
# openssl-3.6.0        | 9.0 MB    | ####9      |  49%
#
# botocore-1.40.70     | 7.8 MB    | ########8  |  88%
# openssl-3.6.0        | 9.0 MB    | #####      |  51%
#
# botocore-1.40.70     | 7.8 MB    | #########  |  90%
# openssl-3.6.0        | 9.0 MB    | #####2     |  52%
#
# botocore-1.40.70     | 7.8 MB    | #########2 |  92%
# openssl-3.6.0        | 9.0 MB    | #####3     |  54%
#
# botocore-1.40.70     | 7.8 MB    | #########4 |  94%
# openssl-3.6.0        | 9.0 MB    | #####5     |  56%
#
# botocore-1.40.70     | 7.8 MB    | #########6 |  97%
# openssl-3.6.0        | 9.0 MB    | #####7     |  57%
#
# botocore-1.40.70     | 7.8 MB    | #########8 |  99%
# openssl-3.6.0        | 9.0 MB    | #####8     |  59%
#
# botocore-1.40.70     | 7.8 MB    | ########## | 100%
# openssl-3.6.0        | 9.0 MB    | ######     |  61%
# openssl-3.6.0        | 9.0 MB    | ######2    |  62%
# openssl-3.6.0        | 9.0 MB    | ######5    |  65%
# openssl-3.6.0        | 9.0 MB    | ######6    |  67%
# openssl-3.6.0        | 9.0 MB    | ######8    |  69%
# openssl-3.6.0        | 9.0 MB    | ######9    |  70%
# openssl-3.6.0        | 9.0 MB    | #######1   |  72%
# openssl-3.6.0        | 9.0 MB    | #######3   |  73%
# openssl-3.6.0        | 9.0 MB    | #######5   |  75%
# openssl-3.6.0        | 9.0 MB    | #######7   |  77%
# openssl-3.6.0        | 9.0 MB    | #######9   |  79%
# openssl-3.6.0        | 9.0 MB    | ########1  |  82%
# openssl-3.6.0        | 9.0 MB    | ########3  |  83%
# openssl-3.6.0        | 9.0 MB    | ########5  |  86%
# openssl-3.6.0        | 9.0 MB    | ########7  |  88%
# openssl-3.6.0        | 9.0 MB    | ########9  |  90%
# openssl-3.6.0        | 9.0 MB    | #########1 |  91%
# openssl-3.6.0        | 9.0 MB    | #########2 |  93%
# openssl-3.6.0        | 9.0 MB    | #########4 |  94%
# openssl-3.6.0        | 9.0 MB    | #########6 |  97%
# openssl-3.6.0        | 9.0 MB    | #########8 |  99%
# openssl-3.6.0        | 9.0 MB    | ########## | 100%
# openssl-3.6.0        | 9.0 MB    | ########## | 100%
#
# botocore-1.40.70     | 7.8 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                                       done
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Channels:
#  - conda-forge
#  - defaults
# Platform: win-64
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\hp\anaconda3
#
#   added / updated specs:
#     - pandas
#     - pymysql
#     - sqlalchemy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     pandas-2.3.3               |  py312hc128f0a_2        13.1 MB  conda-forge
#     pymysql-1.1.2              |     pyhcf101f3_0          45 KB  conda-forge
#     sqlalchemy-2.0.44          |  py312he06e257_0         3.4 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        16.6 MB
#
# The following NEW packages will be INSTALLED:
#
#   pymysql            conda-forge/noarch::pymysql-1.1.2-pyhcf101f3_0
#
# The following packages will be UPDATED:
#
#   pandas             pkgs/main::pandas-2.2.2-py312h0158946~ --> conda-forge::pandas-2.3.3-py312hc128f0a_2
#   sqlalchemy         pkgs/main::sqlalchemy-2.0.34-py312h54~ --> conda-forge::sqlalchemy-2.0.44-py312he06e257_0
#
#
#
# Downloading and Extracting Packages: ...working...
# pandas-2.3.3         | 13.1 MB   |            |   0%
#
# sqlalchemy-2.0.44    | 3.4 MB    |            |   0%
#
#
# pymysql-1.1.2        | 45 KB     |            |   0%
#
# sqlalchemy-2.0.44    | 3.4 MB    |            |   0%
#
# sqlalchemy-2.0.44    | 3.4 MB    | 6          |   7%
#
#
# pymysql-1.1.2        | 45 KB     | ###5       |  36%
#
#
# pymysql-1.1.2        | 45 KB     | ########## | 100%
#
# sqlalchemy-2.0.44    | 3.4 MB    | #2         |  13%
#
#
# pymysql-1.1.2        | 45 KB     | ########## | 100%
#
#
# pymysql-1.1.2        | 45 KB     | ########## | 100%
#
# sqlalchemy-2.0.44    | 3.4 MB    | ##2        |  23%
#
# sqlalchemy-2.0.44    | 3.4 MB    | ##8        |  28%
# pandas-2.3.3         | 13.1 MB   |            |   0%
#
# sqlalchemy-2.0.44    | 3.4 MB    | ###3       |  34%
#
# sqlalchemy-2.0.44    | 3.4 MB    | ###7       |  38%
# pandas-2.3.3         | 13.1 MB   |            |   1%
# pandas-2.3.3         | 13.1 MB   | 1          |   1%
#
# sqlalchemy-2.0.44    | 3.4 MB    | ####1      |  42%
#
# sqlalchemy-2.0.44    | 3.4 MB    | ####4      |  45%
# pandas-2.3.3         | 13.1 MB   | 1          |   2%
# pandas-2.3.3         | 13.1 MB   | 2          |   2%
#
# sqlalchemy-2.0.44    | 3.4 MB    | ####8      |  48%
# pandas-2.3.3         | 13.1 MB   | 2          |   3%
#
# sqlalchemy-2.0.44    | 3.4 MB    | #####1     |  51%
#
# sqlalchemy-2.0.44    | 3.4 MB    | #####4     |  54%
# pandas-2.3.3         | 13.1 MB   | 3          |   3%
# pandas-2.3.3         | 13.1 MB   | 3          |   3%
#
# sqlalchemy-2.0.44    | 3.4 MB    | #####6     |  56%
#
# sqlalchemy-2.0.44    | 3.4 MB    | #####8     |  59%
# pandas-2.3.3         | 13.1 MB   | 3          |   4%
#
# sqlalchemy-2.0.44    | 3.4 MB    | ######     |  61%
#
# sqlalchemy-2.0.44    | 3.4 MB    | ######2    |  63%
# pandas-2.3.3         | 13.1 MB   | 4          |   4%
# pandas-2.3.3         | 13.1 MB   | 4          |   4%
#
# sqlalchemy-2.0.44    | 3.4 MB    | ######4    |  65%
# pandas-2.3.3         | 13.1 MB   | 4          |   5%
#
# sqlalchemy-2.0.44    | 3.4 MB    | ######6    |  67%
#
# sqlalchemy-2.0.44    | 3.4 MB    | ######7    |  68%
# pandas-2.3.3         | 13.1 MB   | 4          |   5%
#
# sqlalchemy-2.0.44    | 3.4 MB    | ######9    |  69%
#
# sqlalchemy-2.0.44    | 3.4 MB    | #######1   |  71%
# pandas-2.3.3         | 13.1 MB   | 5          |   5%
#
# sqlalchemy-2.0.44    | 3.4 MB    | #######3   |  73%
# pandas-2.3.3         | 13.1 MB   | 5          |   5%
#
# sqlalchemy-2.0.44    | 3.4 MB    | #######4   |  74%
#
# sqlalchemy-2.0.44    | 3.4 MB    | #######6   |  77%
# pandas-2.3.3         | 13.1 MB   | 5          |   6%
#
# sqlalchemy-2.0.44    | 3.4 MB    | ########   |  81%
# pandas-2.3.3         | 13.1 MB   | 5          |   6%
#
# sqlalchemy-2.0.44    | 3.4 MB    | ########5  |  85%
# pandas-2.3.3         | 13.1 MB   | 6          |   6%
#
# sqlalchemy-2.0.44    | 3.4 MB    | ########9  |  89%
#
# sqlalchemy-2.0.44    | 3.4 MB    | #########3 |  94%
# pandas-2.3.3         | 13.1 MB   | 6          |   7%
# pandas-2.3.3         | 13.1 MB   | 6          |   7%
#
# sqlalchemy-2.0.44    | 3.4 MB    | #########7 |  97%
#
# sqlalchemy-2.0.44    | 3.4 MB    | ########## | 100%
# pandas-2.3.3         | 13.1 MB   | 7          |   7%
#
# sqlalchemy-2.0.44    | 3.4 MB    | ########## | 100%
# pandas-2.3.3         | 13.1 MB   | 7          |   7%
# pandas-2.3.3         | 13.1 MB   | 7          |   8%
# pandas-2.3.3         | 13.1 MB   | 8          |   8%
# pandas-2.3.3         | 13.1 MB   | 8          |   8%
# pandas-2.3.3         | 13.1 MB   | 8          |   9%
# pandas-2.3.3         | 13.1 MB   | 9          |   9%
# pandas-2.3.3         | 13.1 MB   | 9          |  10%
# pandas-2.3.3         | 13.1 MB   | #          |  10%
# pandas-2.3.3         | 13.1 MB   | #          |  11%
# pandas-2.3.3         | 13.1 MB   | #1         |  12%
# pandas-2.3.3         | 13.1 MB   | #2         |  12%
# pandas-2.3.3         | 13.1 MB   | #3         |  13%
# pandas-2.3.3         | 13.1 MB   | #3         |  14%
# pandas-2.3.3         | 13.1 MB   | #4         |  15%
# pandas-2.3.3         | 13.1 MB   | #6         |  16%
#
# sqlalchemy-2.0.44    | 3.4 MB    | ########## | 100%
# pandas-2.3.3         | 13.1 MB   | #7         |  17%
# pandas-2.3.3         | 13.1 MB   | #8         |  18%
# pandas-2.3.3         | 13.1 MB   | #9         |  20%
# pandas-2.3.3         | 13.1 MB   | ##         |  21%
# pandas-2.3.3         | 13.1 MB   | ##1        |  22%
# pandas-2.3.3         | 13.1 MB   | ##2        |  23%
# pandas-2.3.3         | 13.1 MB   | ##4        |  25%
# pandas-2.3.3         | 13.1 MB   | ##5        |  26%
# pandas-2.3.3         | 13.1 MB   | ##7        |  27%
# pandas-2.3.3         | 13.1 MB   | ##8        |  29%
# pandas-2.3.3         | 13.1 MB   | ##9        |  30%
# pandas-2.3.3         | 13.1 MB   | ###1       |  32%
# pandas-2.3.3         | 13.1 MB   | ###2       |  33%
# pandas-2.3.3         | 13.1 MB   | ###4       |  34%
# pandas-2.3.3         | 13.1 MB   | ###5       |  35%
# pandas-2.3.3         | 13.1 MB   | ###6       |  36%
# pandas-2.3.3         | 13.1 MB   | ###7       |  38%
# pandas-2.3.3         | 13.1 MB   | ###8       |  39%
# pandas-2.3.3         | 13.1 MB   | ###9       |  40%
# pandas-2.3.3         | 13.1 MB   | ####1      |  41%
# pandas-2.3.3         | 13.1 MB   | ####3      |  43%
# pandas-2.3.3         | 13.1 MB   | ####4      |  44%
# pandas-2.3.3         | 13.1 MB   | ####6      |  46%
# pandas-2.3.3         | 13.1 MB   | ####7      |  47%
# pandas-2.3.3         | 13.1 MB   | ####8      |  49%
# pandas-2.3.3         | 13.1 MB   | ####9      |  50%
# pandas-2.3.3         | 13.1 MB   | #####1     |  51%
# pandas-2.3.3         | 13.1 MB   | #####2     |  52%
# pandas-2.3.3         | 13.1 MB   | #####3     |  53%
# pandas-2.3.3         | 13.1 MB   | #####4     |  55%
# pandas-2.3.3         | 13.1 MB   | #####6     |  56%
# pandas-2.3.3         | 13.1 MB   | #####7     |  58%
# pandas-2.3.3         | 13.1 MB   | #####8     |  59%
# pandas-2.3.3         | 13.1 MB   | ######     |  60%
# pandas-2.3.3         | 13.1 MB   | ######1    |  62%
# pandas-2.3.3         | 13.1 MB   | ######3    |  63%
# pandas-2.3.3         | 13.1 MB   | ######4    |  64%
# pandas-2.3.3         | 13.1 MB   | ######5    |  65%
# pandas-2.3.3         | 13.1 MB   | ######6    |  66%
# pandas-2.3.3         | 13.1 MB   | ######7    |  68%
# pandas-2.3.3         | 13.1 MB   | ######8    |  68%
# pandas-2.3.3         | 13.1 MB   | ######9    |  69%
# pandas-2.3.3         | 13.1 MB   | #######    |  70%
# pandas-2.3.3         | 13.1 MB   | #######    |  71%
# pandas-2.3.3         | 13.1 MB   | #######1   |  72%
# pandas-2.3.3         | 13.1 MB   | #######2   |  73%
# pandas-2.3.3         | 13.1 MB   | #######3   |  74%
# pandas-2.3.3         | 13.1 MB   | #######4   |  75%
# pandas-2.3.3         | 13.1 MB   | #######5   |  76%
# pandas-2.3.3         | 13.1 MB   | #######6   |  77%
# pandas-2.3.3         | 13.1 MB   | #######7   |  78%
# pandas-2.3.3         | 13.1 MB   | #######8   |  79%
# pandas-2.3.3         | 13.1 MB   | #######9   |  80%
# pandas-2.3.3         | 13.1 MB   | ########   |  80%
# pandas-2.3.3         | 13.1 MB   | ########1  |  81%
# pandas-2.3.3         | 13.1 MB   | ########1  |  82%
# pandas-2.3.3         | 13.1 MB   | ########2  |  83%
# pandas-2.3.3         | 13.1 MB   | ########3  |  83%
# pandas-2.3.3         | 13.1 MB   | ########4  |  85%
# pandas-2.3.3         | 13.1 MB   | ########5  |  85%
# pandas-2.3.3         | 13.1 MB   | ########6  |  86%
# pandas-2.3.3         | 13.1 MB   | ########7  |  87%
# pandas-2.3.3         | 13.1 MB   | ########8  |  88%
# pandas-2.3.3         | 13.1 MB   | ########9  |  89%
# pandas-2.3.3         | 13.1 MB   | #########  |  90%
# pandas-2.3.3         | 13.1 MB   | #########1 |  91%
# pandas-2.3.3         | 13.1 MB   | #########2 |  92%
# pandas-2.3.3         | 13.1 MB   | #########2 |  93%
# pandas-2.3.3         | 13.1 MB   | #########3 |  93%
# pandas-2.3.3         | 13.1 MB   | #########4 |  94%
# pandas-2.3.3         | 13.1 MB   | #########4 |  95%
# pandas-2.3.3         | 13.1 MB   | #########5 |  95%
# pandas-2.3.3         | 13.1 MB   | #########6 |  96%
# pandas-2.3.3         | 13.1 MB   | #########6 |  97%
# pandas-2.3.3         | 13.1 MB   | #########7 |  97%
# pandas-2.3.3         | 13.1 MB   | #########8 |  98%
# pandas-2.3.3         | 13.1 MB   | #########8 |  99%
# pandas-2.3.3         | 13.1 MB   | #########9 | 100%
# pandas-2.3.3         | 13.1 MB   | ########## | 100%
# pandas-2.3.3         | 13.1 MB   | ########## | 100%
#
#
#
#
#
#
#                                                       done
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
